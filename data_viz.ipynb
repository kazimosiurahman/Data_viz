# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
x = np.arange(0,10,0.2)
y = np.sin(x)
z = np.cos(x)

# %%
#to check the availability of various styles
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#using the ggplot style the below function is used to set
plt.style.use('ggplot')

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.plot(y,z)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Different grpahical methods when plotted against each other")
# Out:
# Text(0.5, 1.0, 'Different grpahical methods when plotted against each other')

# %%
 plt.scatter(y,z)

# %%
#plotting data from file using pandas
path = '../Data Visualization with Python/Data/GoldPrice.csv'
df=pd.read_csv(path,index_col='date')

# %%
df.head()
# Out:
#          value
# date
# 1950-12  34.72
# 1951-12  34.66
# 1952-12  34.79
# 1953-12  34.85
# 1954-12  35.04

# %%
#taking the first 30 values to plot from the dataframe
plt.plot(df['value'][0:30])

# %%
#drawing multiple plots in a file, 
#drawing multiple plots in subplots
#you can also plot the figures like before to overlap

plt.plot(x,y,x,z)

# %%
#moving ahead with subplots
plt.subplot(1,2,1)
plt.title("1st chart (Sin)")
plt.plot(x,y,'b')

plt.subplot(1,2,2)
plt.title("2nd Chart (Cos Inveresed)")
plt.plot(y,x,'r')
plt.tight_layout()

# %%
#object oriented way single plot

#figure is an object created. the size parameters can be adjusted
# in figure there is a method call axes which acts like aspect ration
fig = plt.figure(figsize=(10,8))
ax=fig.add_axes([0.1,0.1,0.9,0.5])
ax.plot(x,y,'b')
ax.plot(x,y,x,z)

# %%
#Object Oriented way of Overlapping plot
fig = plt.figure()

ax1=fig.add_axes([0.1,0.1,0.9,0.9])
ax2=fig.add_axes([0.4,0.7,0.25,0.25])
ax1.plot(x,y,'m')
ax2.plot(x,y,'b')
ax1.set_title("Bigger graph",color='black')
ax2.set_title("Smaller graph",color='black')
# Out:
# Text(0.5, 1.0, 'Smaller graph')

# %%
fig = plt.figure()
x = np.arange(0,10,1)
y = np.square(x)
ax1= fig.add_axes([0.1,0.1,0.9,0.9])
ax2 = fig.add_axes([0.1,0.3,0.25,0.25])
ax1.plot(x,y,color='b')
ax2.plot(x,y,color='r')
ax1.set_title("Bigger graph", color="black")
ax2.set_title("Smaller graph", color="black")
# Out:
# Text(0.5, 1.0, 'Smaller graph')

# %%
#object oriented way : subplotting
fig,ax=plt.subplots(3,3,figsize=(10,5))
# fig = plt.figure()
ax[0,1].plot(x,y,'b')
ax[0,1].set_xlabel("X")
ax[0,1].set_ylabel("Y")
ax[0,1].set_title("1st Chart",color='black')

# ax[1].plot(y,x,'r')
# ax[1].set_xlabel("X")
# ax[1].set_ylabel("Y")
# ax[1].set_title("2nd Chart",color='black')
plt.tight_layout()

# %%
data = np.random.randn(1000,1)
plt.hist(data,40);

# %%
#plotting a pie chart for different revenues in time
revenue = [100,200,156,228,500,432]
plt.pie(revenue,shadow=True);

# %%
#displaying a bar chart, when the data is categorical . summation of all the category value
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.3,0.9])
ax.bar(x = ['Male','Female'] ,height = [200,300] ,width = 0.7 ) 
# plt.tight_layout()
#to design the same plot horizontally you use another method called barh
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.9,0.3])
ax1.barh(y = ['Male','Female'] ,width = [200,300],height =0.6)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
x = np.arange(0.1,10,0.2)
y = np.sin(x)
ax.plot(x,y,'m',ls='--',lw = 2,marker='p',markerfacecolor='b');
ax.legend(["dashed with Marker p"],loc=9);
# ax.plot(x,y+1,'b');
# ax.plot(x,y+2,'#FF9000',marker='o',markersize=5,lw=2,ls='--');

# %%
fig = plt.figure()
#to know the properties of the figure object created use the .properties option
fig.properties()['size_inches']
# Out:
# array([6., 4.])

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])

y = np.sin(x)
ax.plot(x,y,'r',label='Sine')
ax.plot(y,x,'b',label='Inverse of Sine')
# ax.plot(x,y+10,'b',label='Inverse of Sine')
ax.legend()
fig.savefig('./Sine_inverse.jpg')

# %%
#changing the axis range
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
x = np.arange(0,5,0.01)
y = np.sin(x)
ax.plot(x,y)
ax.set_xlim([-5,0.5])
ax.set_ylim([-1,1.5])
# Out:
# (-1, 1.5)

# %%
#till now the plottings have been done on a linear scale. When you have huge amount of data, then we need to get to a log scale
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.set_yscale('log')
ax.set_xticks([0,2.5,5])
ax.plot(x,x*x*x*x*x)

# %%
#step plot where the connections are not smooth as earlier
plt.style.use('ggplot')
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
x = np.arange(0.1,10,0.3)
y = np.sin(x)

ax.step(x,y,lw=3)

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
x = np.arange(1,20,0.2)
y = np.cos(x)
ax.fill_between(x,y,0.3*y,color='#FF9F00')
ax.set_xlim([1.5,11.0])
ax.set_ylim([-1,0.25])
# ax.plot(x,y)
# Out:
# (-1, 0.25)

# %%
#Using your own custom grid
plt.style.use('default')
fig = plt.figure(figsize=(3,2))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.grid(color='b',ls = 'dashed')
ax.plot(x,y,'r')

# %%
#Adding text annotations to a graph
plt.style.use('default')
fig = plt.figure(figsize=(3,2))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
y = x*x
ax.grid(color='b',ls = 'dashed')
ax.plot(x,y,'r')
ax.text(8,200,"$y = x^2$",fontsize=15,color='black')
# Out:
# Text(8, 200, '$y = x^2$')

# %%
 sns.get_dataset_names()
# Out:
# C:\tools\Anaconda3\envs\pytorch\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\tools\Anaconda3\envs\pytorch\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#count plot usually when one variable is categorical
titanic.sex.unique()
titanic['class'].unique()
# Out:
# [Third, First, Second]
# Categories (3, object): [Third, First, Second]

# %%
sns.countplot(x = 'class',data=titanic)

# %%
#when you wish to add another dimension to the label sex let's say categorising them according to classes use hue
sns.countplot(x='sex',data=titanic,hue='class')

# %%
#strip plot is like scatterplot however for categorical 
# sns.countplot(x='sex',data=tips,hue='day')
sns.stripplot(x='sex',y='total_bill',hue='day',data=tips,)

# %%
#trying swarm plot on the same set 
#swarm plot is similar to strip plot without any overlapping
#comparing the above and below charts, male and femlae plots have kind of overlapped , whereas in swarm it has spread
sns.swarmplot(x='sex',y='total_bill',hue='day',data=tips,)

# %%
#distribution of the total bill 
sns.violinplot(x='sex',y='total_bill',data=tips,)

# %%
#bar plot - point estimates for categorical data
# box plot - distribution for each category
sns.barplot(x='sex',y='age',hue='class',data=titanic,order=['female','male'],estimator=np.std,palette='Set1')

# %%
sns.boxplot(x='sex',y='age',hue='class',data=titanic,)

# %% [markdown]
# Relationship Plot

# %%
#rel plot exists between numerical values in categorical
#visualising five dimension of a dataframe at a go
sns.relplot(data=titanic,x='age',y='fare',col='class',kind='scatter',hue='pclass',palette='coolwarm',row='survived')

# %%
#the scatter plot and the line plot can also be plotted using the specific methods in seaborn as well than using the generalised version of relplot
sns.scatterplot(data=titanic,x='age',y='fare',)

# %%
sns.lineplot(data=titanic,x='age',y='fare',)

# %% [markdown]
# Regression Plots
# whether we can fit a linear model to the data or not - understanding trends

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='smoker',markers=['o','x']#,palette='coolwarm')
,palette=dict(No='r',Yes='g'))

# %%
#to segregate the above data in terms of male and female, we can use the row or column field as before
sns.lmplot(data=tips,x='total_bill',y='tip',col='smoker',col_wrap=2,fit_reg=True,order=3)

# %%
#heatmap
